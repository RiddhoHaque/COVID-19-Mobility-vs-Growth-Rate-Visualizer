# %%
import pandas as pd
import pandasql as ps

df=pd.read_csv('Global_Mobility_Report.csv')
    


qBD="Select * from df where country_region='Bangladesh'"
df_BD=ps.sqldf(qBD, locals())
qVN="Select * from df where country_region='Vietnam' and sub_region_1 is NULL"
df_VN=ps.sqldf(qVN, locals())
df_VN
# Out:
# c:\users\asus\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     country_region_code country_region sub_region_1 sub_region_2  \
# 0                    VN        Vietnam         None         None
# 1                    VN        Vietnam         None         None
# 2                    VN        Vietnam         None         None
# 3                    VN        Vietnam         None         None
# 4                    VN        Vietnam         None         None
# ..                  ...            ...          ...          ...
# 129                  VN        Vietnam         None         None
# 130                  VN        Vietnam         None         None
# 131                  VN        Vietnam         None         None
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(df_BD['date'], -df_BD['grocery_and_pharmacy_percent_change_from_baseline'], color='g')
plt.plot(df_VN['date'], -df_VN['grocery_and_pharmacy_percent_change_from_baseline'], color='orange')
plt.xticks('2020-02-15')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.plot(df_BD['date'], -df_BD['retail_and_recreation_percent_change_from_baseline'], color='g', label='Bangladesh')
plt.plot(df_VN['date'], -df_VN['retail_and_recreation_percent_change_from_baseline'], color='orange', label='Vietnam')
plt.xticks(['2020-02-15', '2020-03-15', '2020-04-15', '2020-05-15', '2020-06-15'])
plt.axvline(x='2020-03-17', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-03-26', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-05-25', ls='--', lw=0.5, color='black')
plt.legend()
plt.title('Timeline of Mobility Changes (Recreation spots)')
plt.xlabel('Dates')
plt.ylabel('Community'+'\n'+'mobility'+'\n'+'reduction (%)', fontsize=10, rotation=0)
ax=plt.gca()
fig1 = plt.gcf()
ax.yaxis.set_label_coords(-0.20,0.5)
plt.show()
fig1.savefig("Recreation_Mobility.jpg", dpi=100)

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.plot(df_BD['date'], -df_BD['grocery_and_pharmacy_percent_change_from_baseline'], color='g', label='Bangladesh')
plt.plot(df_VN['date'], -df_VN['grocery_and_pharmacy_percent_change_from_baseline'], color='orange', label='Vietnam')
plt.xticks(['2020-02-15', '2020-03-15', '2020-04-15', '2020-05-15', '2020-06-15'])
plt.axvline(x='2020-03-17', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-03-26', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-05-25', ls='--', lw=0.5, color='black')
plt.legend()
plt.title('Timeline of Mobility Changes (Groceries and Pharmacies)')
plt.xlabel('Dates')
plt.ylabel('Community'+'\n'+'mobility'+'\n'+'reduction (%)', fontsize=10, rotation=0)
ax=plt.gca()
fig1 = plt.gcf()
ax.yaxis.set_label_coords(-0.20,0.5)
plt.show()
fig1.savefig("Grocery_and_Pharmacy_Mobility.jpg", dpi=100)

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.plot(df_BD['date'], -df_BD['parks_percent_change_from_baseline'], color='g', label='Bangladesh')
plt.plot(df_VN['date'], -df_VN['parks_percent_change_from_baseline'], color='orange', label='Vietnam')
plt.xticks(['2020-02-15', '2020-03-15', '2020-04-15', '2020-05-15', '2020-06-15'])
plt.axvline(x='2020-03-17', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-03-26', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-05-25', ls='--', lw=0.5, color='black')
plt.legend()
plt.title('Timeline of Mobility Changes (Parks)')
plt.xlabel('Dates')
plt.ylabel('Community'+'\n'+'mobility'+'\n'+'reduction (%)', fontsize=10, rotation=0)
ax=plt.gca()
fig1 = plt.gcf()
ax.yaxis.set_label_coords(-0.20,0.5)
plt.show()
fig1.savefig("Parks_Mobility.jpg", dpi=100)

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.plot(df_BD['date'], -df_BD['transit_stations_percent_change_from_baseline'], color='g', label='Bangladesh')
plt.plot(df_VN['date'], -df_VN['transit_stations_percent_change_from_baseline'], color='orange', label='Vietnam')
plt.xticks(['2020-02-15', '2020-03-15', '2020-04-15', '2020-05-15', '2020-06-15'])
plt.axvline(x='2020-03-17', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-03-26', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-05-25', ls='--', lw=0.5, color='black')
plt.legend()
plt.title('Timeline of Mobility Changes (Public Transportation Stations)')
plt.xlabel('Dates')
plt.ylabel('Community'+'\n'+'mobility'+'\n'+'reduction (%)', fontsize=10, rotation=0)
ax=plt.gca()
fig1 = plt.gcf()
ax.yaxis.set_label_coords(-0.20,0.5)
plt.show()
fig1.savefig("Transit_Stations_Mobility.jpg", dpi=100)

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.plot(df_BD['date'], -df_BD['workplaces_percent_change_from_baseline'], color='g', label='Bangladesh')
plt.plot(df_VN['date'], -df_VN['workplaces_percent_change_from_baseline'], color='orange', label='Vietnam')
plt.xticks(['2020-02-15', '2020-03-15', '2020-04-15', '2020-05-15', '2020-06-15'])
plt.axvline(x='2020-03-17', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-03-26', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-05-25', ls='--', lw=0.5, color='black')
plt.legend()
plt.title('Timeline of Mobility Changes (Work Places)')
plt.xlabel('Dates')
plt.ylabel('Community'+'\n'+'mobility'+'\n'+'reduction (%)', fontsize=10, rotation=0)
ax=plt.gca()
fig1 = plt.gcf()
ax.yaxis.set_label_coords(-0.20,0.5)
plt.show()
fig1.savefig("Work_Places_Mobility.jpg", dpi=100)

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})
plt.plot(df_BD['date'], -df_BD['residential_percent_change_from_baseline'], color='g', label='Bangladesh')
plt.plot(df_VN['date'], -df_VN['residential_percent_change_from_baseline'], color='orange', label='Vietnam')
plt.xticks(['2020-02-15', '2020-03-15', '2020-04-15', '2020-05-15', '2020-06-15'])
plt.axvline(x='2020-03-17', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-03-26', ls='--', lw=0.5, color='black')
plt.axvline(x='2020-05-25', ls='--', lw=0.5, color='black')
plt.legend()
plt.title('Timeline of Mobility Changes (Residential Places)')
plt.xlabel('Dates')
plt.ylabel('Community'+'\n'+'mobility'+'\n'+'reduction (%)', fontsize=10, rotation=0)
ax=plt.gca()
fig1 = plt.gcf()
ax.yaxis.set_label_coords(-0.20,0.5)
plt.show()
fig1.savefig("Residential_Mobility.jpg", dpi=100)

# %%
import pandas as pd
import pandasql as ps

countries=['Italy', 'Bangladesh', 'Vietnam', 'Sweden', 'New Zealand', 'Singapore', 'Indonesia', 'Spain', 'Portugal', 'UK', 'Japan', 'Sri Lanka']
colours=['tab:brown', 'tab:green', 'tab:orange', 'b', 'k', 'tab:pink', 'm', 'y', 'tab:purple', 'tab:cyan', 'tab:red', 'tab:brown']
pop_density=[206, 1115.62, 314, 25, 46, 8358, 140.08, 243, 288, 430, 899, 341]
population=[60461826, 164689383, 97338579, 10099265, 4822233, 5850342, 273397681, 46754118,  10197799, 67871466, 126490626, 21412817]
confirmed_df=pd.read_csv('time_series_covid19_confirmed_global.csv')
recovered_df=pd.read_csv('time_series_covid19_recovered_global.csv')
death_df=pd.read_csv('time_series_covid19_deaths_global.csv')

def get_day(days, months):
    if(months>=2):
        days+=31
    if(months>=3):
        days+=29
    if(months>=4):
        days+=31
    if(months>=5):
        days+=30
    if(months>=6):
        days+=31
    if(months>=7):
        days+=30
    if(months>=8):
        days+=31
    if(months>=9):
        days+=31
    if(months>=10):
        days+=30
    if(months>=11):
        days+=31
    if(months>=12):
        days+=30
    return days

def get_day_csse(str):
    parts=str.split("/")
    months=int(parts[0])
    days=int(parts[1])
    years=int(parts[2])
    return get_day(days, months)

def get_day_mobility(str):
    parts=str.split("-")
    years=int(parts[0])
    months=int(parts[1])
    days=int(parts[2])
    return get_day(days, months)

st_date=get_day_mobility("2020-02-15")
ed_date=get_day_mobility("2020-06-27")
print(get_day_csse("6/1/20"))

case_info=[[0 for j in range(len(countries))] for i in range(366)]
mobility_info=[[0 for j in range(len(countries))] for i in range(366)]
countryIndex=0
for country in countries:
    country_alt=country
    if(country=='UK'):
        country_alt='United Kingdom';
    qCon="Select * from confirmed_df where [Country/Region]='"+country_alt+"' and [Province/State] is null"
    qRec="Select * from recovered_df where [Country/Region]='"+country_alt+"' and [Province/State] is null"
    qDeath="Select * from death_df where [Country/Region]='"+country_alt+"' and [Province/State] is null"
    cases_country=ps.sqldf(qCon, locals())
    recovered_country=ps.sqldf(qRec, locals())
    death_country=ps.sqldf(qDeath, locals())
    for column in cases_country.columns:
        if(column[0].isdigit()):
            day=get_day_csse(column)
            val=0
            for idx, row in cases_country.iterrows():
                val=row[column]
            if(day>=st_date and day<=ed_date):
                if countryIndex==0 and day==get_day_csse("6/1/20"):
                    print('Confirmed '+str(val))
                case_info[day][countryIndex]=val
    for column in recovered_country.columns:
        if(column[0].isdigit()):
            day=get_day_csse(column)
            val=0
            for idx, row in recovered_country.iterrows():
                val=row[column]
            if(day>=st_date and day<=ed_date):
                if countryIndex==0 and day==get_day_csse("6/1/20"):
                    print('Recovered '+str(val))
                case_info[day][countryIndex]-=val
    for column in death_country.columns:
        if(column[0].isdigit()):
            day=get_day_csse(column)
            val=0
            for idx, row in death_country.iterrows():
                val=row[column]
            if(day>=st_date and day<=ed_date):
                if countryIndex==0 and day==get_day_csse("6/1/20"):
                    print('Deaths '+str(val))
                case_info[day][countryIndex]-=val
    qMob="Select * from df where country_region='"+country_alt+"' and sub_region_1 is NULL"
    mob_df=ps.sqldf(qMob, locals())
    for idx, rows in mob_df.iterrows():
        day=get_day_mobility(rows["date"])
        val=rows["retail_and_recreation_percent_change_from_baseline"]
        val+=rows["transit_stations_percent_change_from_baseline"]
        val+=rows["workplaces_percent_change_from_baseline"]
        val/=3
        mobility_info[day][countryIndex]=val
    countryIndex+=1 

rev_mobility_info=[[0 for j in range(len(countries))] for i in range(366)]

running_avg_interval=3
for day in range(366):
    for countryIndex in range(len(countries)):
        sum=0
        cnt=0
        for i in range(running_avg_interval):
            if day-i>=st_date:
                sum+=mobility_info[day-i][countryIndex]
                cnt+=1
        if(cnt==0):
            rev_mobility_info[day][countryIndex]=sum
        else:
            rev_mobility_info[day][countryIndex]=(sum*1.0)/(cnt*1.0)
mobility_info=[[rev_mobility_info[i][j] for j in range(len(countries))] for i in range(366)]
# Out:
# 153
# Confirmed 233197
# Confirmed 240760
# Recovered 158355
# Recovered 190717
# Deaths 33475
# Deaths 34788

# %%
#from matplotlib import rcParams
import math
import matplotlib.pyplot as plt
from matplotlib import rcParams
#rcParams.update({'figure.autolayout': True})
def get_date(day):
    days_in_month=[31, 29, 31, 30, 31, 30, 31]
    idx=0
    month=1
    while days_in_month[idx]<day:
        month+=1
        day-=days_in_month[idx]
        idx+=1
    return str(day)+"/"+str(month)

def distort(val):
    if val==0:
        return 0
    #print(val)
    return math.log10(val)
#print(distort(100000))

def day_num(day):
    if day<10:
        return '00'+str(day)
    if day<100:
        return '0'+str(day)
    return str(day)

mx=5
for i in range(365):
    for j in range(len(countries)):
        if(case_info[i][j]<0):
            print(countries[j], get_date(i), case_info[i][j])
        if(case_info[i][j]>mx):
            mx=distort(case_info[i][j])
for i in range(365):
    if i>=st_date and i<=ed_date:
        active_cases=[distort(case_info[i][j]) for j in range(len(countries))]
        #for j in range(len(population)):
        #    active_cases_per_million[j]/=population[j]
        #    active_cases_per_million[j]*=10000000
        x=active_cases
        #ticks = [0, 5000, 20000, 50000, 100000]
        #plt.xticks(range(5), ticks)
        y=mobility_info[i]
        c=colours
        s=pop_density
        fig = plt.figure(figsize=(8, 8))
        plt.ylim([-100, 30])
        plt.xlim([0, 6])
        ticks=[0, 10, 100, 1000, 10000, 100000, 1000000]
        plt.xticks(range(7), ticks)
        plt.scatter(x=x, y=y, s=s, alpha=0.5, c=c, cmap="Blues", edgecolors="grey", linewidth=2)
        plt.title('Community mobility changes vs COVID19 cases-'+get_date(i))
        plt.ylabel('Mobility change (%)')
        plt.xlabel('Active cases')
        #plt.scatter(x=x, y=y, s=s, alpha=0.5, c=c)
        idx=0
        for country in countries:
            plt.annotate(country, (x[idx], y[idx]))
            idx+=1
        filename='step'+day_num(i)+'.png'
        plt.savefig(filename, dpi=96)
        plt.gca()
# Out:
# Italy 1/6 -176575
# Vietnam 1/6 -274
# New Zealand 1/6 -1485
# Singapore 1/6 -17405
# Spain 1/6 -106584
# Portugal 1/6 -7899
# Japan 1/6 -14063
# Sri Lanka 1/6 -527
# Italy 2/6 -178562
# Vietnam 2/6 -283
# New Zealand 2/6 -1485
# Singapore 2/6 -18344
# Spain 2/6 -106144
# Portugal 2/6 -8207
# Japan 2/6 -14024
# Sri Lanka 2/6 -606
# Italy 3/6 -179655
# Vietnam 3/6 -287
# New Zealand 3/6 -1485
# Singapore 3/6 -18922
# Spain 3/6 -105720
# Portugal 3/6 -8392
# Japan 3/6 -14120
# Sri Lanka 3/6 -652
# Italy 4/6 -180963
# Vietnam 4/6 -287
# New Zealand 4/6 -1482
# Singapore 4/6 -19407
# Spain 4/6 -105725
# Portugal 4/6 -8586
# Japan 4/6 -14044
# Sri Lanka 4/6 -672
# <ipython-input-12-bd111cdcc155>:49: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ...

# %%
#from matplotlib import rcParams
import math
import matplotlib.pyplot as plt
#rcParams.update({'figure.autolayout': True})
def get_date(day):
    days_in_month=[31, 29, 31, 30, 31, 30]
    idx=0
    month=1
    while days_in_month[idx]<day:
        month+=1
        day-=days_in_month[idx]
        idx+=1
    return str(day)+"/"+str(month)

def distort(val):
    if val<=0:
        return 0
    return math.log10(val)
#print(distort(100000))

for i in range(len(countries)):
    x=[]
    y=[]
    c=colours[i]
    for j in range(365):
        if j>=st_date and j<=ed_date:
            x.append(distort(case_info[j][i]))
            y.append(mobility_info[j][i])
    fig = plt.figure(figsize=(8, 8))
    plt.ylim([-100, 30])
    plt.xlim([0, 6])
    ticks=[0, 10, 100, 1000, 10000, 100000, 1000000]
    plt.xticks(range(7), ticks)
    plt.plot(x, y, c)
    plt.title(countries[i]+' Community mobility changes vs COVID19 cases')
    plt.ylabel('Mobility change (%)')
    plt.xlabel('Active cases')
    #plt.scatter(x=x, y=y, s=s, alpha=0.5, c=c)
    filename='Mobility Tracking/'+countries[i]+' mobility.png'
    plt.savefig(filename, dpi=96)
    plt.gca()

# %%
import glob
from PIL import Image

# filepaths
fp_in = "*.png"
fp_out = 'Mobility Tracking/'+"Mobility.gif"

# https://pillow.readthedocs.io/en/stable/handbook/image-file-formats.html#gif
img, *imgs = [Image.open(f) for f in sorted(glob.glob(fp_in))]
img.save(fp=fp_out, format='GIF', append_images=imgs,
         save_all=True, duration=400, loop=0)

# %%
import matplotlib.pyplot as plt
#from matplotlib import rcParams
#rcParams.update({'figure.autolayout': True})
def get_day_mobility(str):
    parts=str.split("-")
    years=int(parts[0])
    months=int(parts[1])
    days=int(parts[2])
    return get_day(days, months)
def distort(val):
    if val==0:
        return 0
    return math.log10(val)
countryIndex=0
for country in countries:
    x=[]
    y=[]
    first=-1
    last=-1
    first_60=-1
    last_60=-1
    for j in range(st_date, ed_date+1):
        x.append(j-st_date)
        y.append(distort(case_info[j][countryIndex]))
        if mobility_info[j][countryIndex]<=-40.0 and first==-1:
            first=j-st_date
        if first!=-1 and mobility_info[j][countryIndex]>=-40.0:
            last=j-st_date
        if mobility_info[j][countryIndex]<=-60.0 and first_60==-1:
            first_60=j-st_date
        if first_60!=-1 and mobility_info[j][countryIndex]>=-60.0:
            last_60=j-st_date
    fig = plt.figure(figsize=(8, 8))
    plt.ylim([0, 7])
    ticks=[0, 10, 100, 1000, 10000, 100000, 1000000]
    plt.yticks(range(7), ticks)
    plt.plot(x, y, colours[countryIndex])
    if first!=-1:
        plt.axvline(x=first, ls='--', lw=1.0, color='blue', label='Date of mobility reduction going down by 40% or less')
    if last!=-1:
        plt.axvline(x=last, ls='--', lw=1.0, color='green', label='Date of mobility reduction going above 40% again')
    if first_60!=-1:
        plt.axvline(x=first_60, ls='--', lw=1.0, color='red', label='Date of mobility reduction going down by 60% or less')
    if last_60!=-1:
        plt.axvline(x=last_60, ls='--', lw=1.0, color='orange', label='Date of mobility reduction going above 60% again')
    plt.title('Timeline of Active Cases in ' + country)
    plt.legend()
    plt.xlabel('Dates')
    plt.ylabel('# of Active Cases')
    plt.xticks([get_day_mobility('2020-02-15')-st_date, get_day_mobility('2020-03-15')-st_date, get_day_mobility('2020-04-15')-st_date, get_day_mobility('2020-05-15')-st_date], ['2020-02-15', '2020-03-15', '2020-04-15', '2020-05-15'])
    plt.savefig("Active Cases/Timeline_of_active_cases in "+country+".png", dpi=100)
    plt.gca()
    countryIndex+=1

# %%
#from matplotlib import rcParams
#rcParams.update({'figure.autolayout': True})
def get_day_mobility(str):
    parts=str.split("-")
    years=int(parts[0])
    months=int(parts[1])
    days=int(parts[2])
    return get_day(days, months)
def distort(val):
    if val==0:
        return 0
    return math.log10(val)
countryIndex=0
for country in countries:
    x=[]
    y=[]
    first=-1
    last=-1
    first_60=-1
    last_60=-1
    for j in range(st_date, ed_date+1):
        x.append(j-st_date)
        y.append(case_info[j][countryIndex])
        if mobility_info[j][countryIndex]<=-40.0 and first==-1:
            first=j-st_date
        if first!=-1 and mobility_info[j][countryIndex]>=-40.0:
            last=j-st_date
        if mobility_info[j][countryIndex]<=-60.0 and first_60==-1:
            first_60=j-st_date
        if first_60!=-1 and mobility_info[j][countryIndex]>=-60.0:
            last_60=j-st_date
    fig = plt.figure(figsize=(8, 8))
    plt.plot(x, y, colours[countryIndex])
    if first!=-1:
        plt.axvline(x=first, ls='--', lw=1.0, color='blue', label='Date of mobility reduction going down by 40% or less')
    if last!=-1:
        plt.axvline(x=last, ls='--', lw=1.0, color='green', label='Date of mobility reduction going above 40% again')
    if first_60!=-1:
        plt.axvline(x=first_60, ls='--', lw=1.0, color='red', label='Date of mobility reduction going down by 60% or less')
    if last_60!=-1:
        plt.axvline(x=last_60, ls='--', lw=1.0, color='orange', label='Date of mobility reduction going above 60% again')
    plt.title('Timeline of Active Cases in ' + country+' (Linear Scale)')
    plt.legend()
    plt.xlabel('Dates')
    plt.ylabel('# of Active Cases')
    plt.xticks([get_day_mobility('2020-02-15')-st_date, get_day_mobility('2020-03-15')-st_date, get_day_mobility('2020-04-15')-st_date, get_day_mobility('2020-05-15')-st_date], ['2020-02-15', '2020-03-15', '2020-04-15', '2020-05-15'])
    plt.savefig("Active Cases/Timeline_of_active_cases in "+country+" (Linear Scale).png", dpi=100)
    plt.gca()
    countryIndex+=1

# %%
import pandas as pd
import pandasql as ps
import math
import matplotlib.pyplot as plt

mobility_df=pd.read_csv('Global_Mobility_Report.csv')
confirmed_df=pd.read_csv('time_series_covid19_confirmed_global.csv')
recovered_df=pd.read_csv('time_series_covid19_recovered_global.csv')
death_df=pd.read_csv('time_series_covid19_deaths_global.csv')

qCountries="Select distinct country_region from mobility_df"
countries=ps.sqldf(qCountries, locals())
def get_day(days, months):
    if(months>=2):
        days+=31
    if(months>=3):
        days+=29
    if(months>=4):
        days+=31
    if(months>=5):
        days+=30
    if(months>=6):
        days+=31
    return days

def get_day_csse(str):
    parts=str.split("/")
    months=int(parts[0])
    days=int(parts[1])
    years=int(parts[2])
    return get_day(days, months)

def get_day_mobility(str):
    parts=str.split("-")
    years=int(parts[0])
    months=int(parts[1])
    days=int(parts[2])
    return get_day(days, months)


st_date=get_day_mobility("2020-02-15")
ed_date=get_day_csse("5/29/20")
ed_date_csse=get_day_csse("6/5/20")

case_info=[[0 for j in range(len(countries))] for i in range(366)]
case_available=[[False]*len(countries) for i in range(366)]
mobility_info=[[0 for j in range(len(countries))] for i in range(366)]
mobility_available=[[False for j in range(len(countries))] for i in range(366)]
countryIndex=0
for country in countries["country_region"]:
    country_alt=country
    if country == "The Bahamas":
        country="Bahamas"
    if country == "Côte d'Ivoire":
        country="Cote d Ivoire"
    if country == "Cape Verde":
        country="Cabo Verde"
    if country=="South Korea":
        country="Korea, South"
    if country=="Myanmar (Burma)":
        country="Burma"
    if country=="Taiwan":
        country="Taiwan*"
    if country=="United States":
        country="US"
    qCon=""
    qRec=""
    qDeath=""
    if country=="Hong Kong":
        qCon="Select * from confirmed_df where [Country/Region]='China' and [Province/State]='"+country+"'"
        qRec="Select * from recovered_df where [Country/Region]='China' and [Province/State]='"+country+"'"
        qDeath="Select * from death_df where [Country/Region]='China' and [Province/State]='"+country+"'"
    else:
        qCon="Select * from confirmed_df where [Country/Region]='"+country+"'"
        qRec="Select * from recovered_df where [Country/Region]='"+country+"'"
        qDeath="Select * from death_df where [Country/Region]='"+country+"'"
    cases_country=ps.sqldf(qCon, locals())
    recovered_country=ps.sqldf(qRec, locals())
    death_country=ps.sqldf(qDeath, locals())
    for column in cases_country.columns:
        if(column[0].isdigit()):
            day=get_day_csse(column)
            val=0
            for idx, row in cases_country.iterrows():
                val+=row[column]
            if(day>=st_date and day<=ed_date):
                case_info[day][countryIndex]=val
                case_available[day][countryIndex]=True
    for column in recovered_country.columns:
        if(column[0].isdigit()):
            day=get_day_csse(column)
            val=0
            for idx, row in recovered_country.iterrows():
                val+=row[column]
            if(day>=st_date and day<=ed_date):
                case_info[day][countryIndex]-=val
    for column in death_country.columns:
        if(column[0].isdigit()):
            day=get_day_csse(column)
            val=0
            for idx, row in death_country.iterrows():
                val+=row[column]
            if(day>=st_date and day<=ed_date):
                case_info[day][countryIndex]-=val
    qMob="Select * from mobility_df where country_region='"+country_alt+"' and sub_region_1 is NULL"
    mob_df=ps.sqldf(qMob, locals())
    for idx, rows in mob_df.iterrows():
        day=get_day_mobility(rows["date"])
        cnt=0
        if(rows["retail_and_recreation_percent_change_from_baseline"] is not None):
            val=rows["retail_and_recreation_percent_change_from_baseline"]
            cnt+=1
        if(rows["transit_stations_percent_change_from_baseline"] is not None):
            val+=rows["transit_stations_percent_change_from_baseline"]
            cnt+=1
        if(rows["workplaces_percent_change_from_baseline"] is not None):
            val+=rows["workplaces_percent_change_from_baseline"]
            cnt+=1
        val/=cnt
        if cnt==0:
            continue
        mobility_info[day][countryIndex]=val
        mobility_available[day][countryIndex]=True
    countryIndex+=1 

rev_mobility_info=[[0 for j in range(len(countries))] for i in range(366)]

running_avg_interval=3
for day in range(366):
    for countryIndex in range(len(countries)):
        sum=0
        cnt=0
        for i in range(running_avg_interval):
            if day-i>=st_date:
                sum+=mobility_info[day-i][countryIndex]
                cnt+=1
        if(cnt==0):
            rev_mobility_info[day][countryIndex]=sum
        else:
            rev_mobility_info[day][countryIndex]=(sum*1.0)/(cnt*1.0)
mobility_info=[[rev_mobility_info[i][j] for j in range(len(countries))] for i in range(366)]
# Out:
# c:\users\asus\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3062: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
def get_doubling_time(st, ed, duration):
    #print(st, ed, duration)
    
    if st==ed:
        return 0
    if ed==1:
        return 0
    if st==0:
        return (duration*math.log(2))/(math.log(ed)) 
    return (duration*math.log(2))/(math.log(ed)-math.log(st))

x=[]
y=[]
c=[]
for day in range(st_date, ed_date+1):
    for ind in range(countryIndex):
        if(mobility_available[day+13][ind] and case_available[day+27][ind]):
            avg_mob=0
            for d in range(14):
                avg_mob+=mobility_info[day+d][ind]
            avg_mob/=14
            if case_info[day+27][ind]>=1000 and case_info[day+14][ind]>=1000 and case_info[day+14][ind]<case_info[day+27][ind]:
                if get_doubling_time(case_info[day+14][ind], case_info[day+27][ind], 14)!=0:
                    x.append(-avg_mob)
                    y.append(1.0/get_doubling_time(case_info[day+14][ind], case_info[day+27][ind], 14))
                    c.append('b')
print(len(x))
print(len(y))
plt.xlabel("Percentage reduction in mobility")
plt.ylabel("Doubling rate of active COVID19 cases")
plt.title("Effect of Lockdown on the doubling rate of COVID-19 worldwide")
plt.scatter(x=x, y=y)
plt.savefig("Lockdown and Doubling rate/Effect of lockdown on doubling rate.png", dpi=100)
plt.gca()
# Out:
# 2296
# 2296

# %%
from scipy.stats import pearsonr
xcorr=[]
ycorr=[]
for v in range(len(x)):
    if math.isnan(x[v]) or math.isnan(y[v]):
        print(v)
    else:
        xcorr.append(x[v])
        ycorr.append(y[v])
corr, _ = pearsonr(xcorr, ycorr)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.910
